# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 8096

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "image-captioning-flickr8k-iu"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'image-captioning-flickr8k-iu'...
# remote: Enumerating objects: 257, done.
# remote: Counting objects: 100% (257/257), done.
# remote: Compressing objects: 100% (182/182), done.
# remote: Total 257 (delta 144), reused 180 (delta 70), pack-reused 0 (from 0)
# Receiving objects: 100% (257/257), 61.97 KiB | 2.38 MiB/s, done.
# Resolving deltas: 100% (144/144), done.
# Repo ready: /kaggle/working/image-captioning-flickr8k-iu
#
# Current working dir: /kaggle/working/image-captioning-flickr8k-iu

# %%
# !python -m scripts.train --config transformer --env kaggle
# Out:
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Image Dir: /kaggle/input/datasets/doduyquynii/flickr8k-toy-model/flickr8k/images
# --> Captions File: /kaggle/input/datasets/doduyquynii/flickr8k-toy-model/flickr8k/captions.txt
# Loading captions...
# Filtering valid images...
# Building vocabulary from Train set...
# Building datasets...
# Loader done: Train (30000), Val (5000), Test (5000)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|███████████████████████████████████████| 20.5M/20.5M [00:00<00:00, 154MB/s]
# Downloading: "https://download.pytorch.org/models/swin_t-704ceda3.pth" to /root/.cache/torch/hub/checkpoints/swin_t-704ceda3.pth
# 100%|█████████████████████████████████████████| 108M/108M [00:00<00:00, 175MB/s]
# --> [Scheduler] StepLR (step_size=5, gamma=0.5)
#
# --> Train on 30000 samples, validate on 5000 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/image-captioning-flickr8k-iu/wandb/run-20260408_163335-2lketxfn
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run transformer_08042026_1632
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/image-captioning
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/image-captioning/runs/2lketxfn
#
# --> Start training in total 30 epochs with cuda device. Start...
#
# Epoch 1/30 - loss: 3.6848 - val_loss: 3.1483
# 	--- Save best at ep 1, val_loss: 3.1483, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_1632_best.pth ---
# Epoch 2/30 - loss: 2.9028 - val_loss: 2.9041
# 	--- Save best at ep 2, val_loss: 2.9041, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_1632_best.pth ---
# Epoch 3/30 - loss: 2.6352 - val_loss: 2.8005
# 	--- Save best at ep 3, val_loss: 2.8005, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_1632_best.pth ---
# Epoch 4/30 - loss: 2.4609 - val_loss: 2.7293
# 	--- Save best at ep 4, val_loss: 2.7293, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_1632_best.pth ---
# Epoch 5/30 - loss: 2.3261 - val_loss: 2.7010
# 	--- Save best at ep 5, val_loss: 2.7010, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_1632_best.pth ---
# Epoch 6/30 - loss: 2.1709 - val_loss: 2.6784
# 	--- Save best at ep 6, val_loss: 2.6784, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_1632_best.pth ---
# Epoch 7/30 - loss: 2.1046 - val_loss: 2.6736
# 	--- Save best at ep 7, val_loss: 2.6736, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_1632_best.pth ---
# Epoch 8/30 - loss: 2.0528 - val_loss: 2.6863
# 	-!- No improvement: 1/10
# Epoch 9/30 - loss: 2.0045 - val_loss: 2.6801
# 	-!- No improvement: 2/10
# Epoch 10/30 - loss: 1.9599 - val_loss: 2.6864
# 	-!- No improvement: 3/10
# Epoch 11/30 - loss: 1.8840 - val_loss: 2.6886
# 	-!- No improvement: 4/10
# Epoch 12/30 - loss: 1.8572 - val_loss: 2.7015
# 	-!- No improvement: 5/10
# Epoch 13/30 - loss: 1.8346 - val_loss: 2.7055
# 	-!- No improvement: 6/10
# Epoch 14/30 - loss: 1.8121 - val_loss: 2.7146
# 	-!- No improvement: 7/10
# Epoch 15/30 - loss: 1.7920 - val_loss: 2.7243
# 	-!- No improvement: 8/10
# Epoch 16/30 - loss: 1.7502 - val_loss: 2.7290
# 	-!- No improvement: 9/10
# Epoch 17/30 - loss: 1.7371 - val_loss: 2.7380
# 	-!- No improvement: 10/10
# 	-_- Early stopping at ep=17
#
# ===================================================
# Evaluate on Test set
# ===================================================
# --> [Evaluation] Đang gom nhóm và đánh giá trên 5000 mẫu (beam)...
# 100%|█████████████████████████████████████████| 157/157 [02:52<00:00,  1.10s/it]
# --> [Evaluation] Hoàn thành sinh caption cho 1000 ảnh duy nhất. Đang tính metrics...
#    BLEU-1: 0.6945
#    BLEU-2: 0.4855
#    BLEU-3: 0.3359
#    BLEU-4: 0.2300
#    METEOR: 0.4715
#    ROUGE-L: 0.5329
#
# Ví dụ 1:
#   Gốc (mẫu): a blond woman in a blue shirt appears to wait for a ride .
#   Dự đoán: a woman in a blue shirt and blue jeans is standing on the street .
# Figure(1000x800)
#
# Ví dụ 2:
#   Gốc (mẫu): a small dogs ears stick up as it runs in the grass .
#   Dự đoán: a small white dog is playing in the grass .
# Figure(1000x800)
#
# Ví dụ 3:
#   Gốc (mẫu): three people in the snow put their gear in .
#   Dự đoán: two people are pulling a sled in the snow .
# Figure(1000x800)
#
# Ví dụ 4:
#   Gốc (mẫu): three children playing in sand at beach
#   Dự đoán: a girl and a girl are playing in the sand .
# Figure(1000x800)
#
# Ví dụ 5:
#   Gốc (mẫu): two women and a child are sitting by a cart of in front of a booth at a medieval .
#   Dự đoán: a group of children sitting on a lawn .
# Figure(1000x800)
#
# Ví dụ 6:
#   Gốc (mẫu): a man sleeping with a bag on his lap on public
#   Dự đoán: a man in a black shirt sits on a subway .
# Figure(1000x800)
#
# Ví dụ 7:
#   Gốc (mẫu): a young girl balances on wooden at the beach .
#   Dự đoán: a little girl is jumping on the beach .
# Figure(1000x800)
#
# Ví dụ 8:
#   Gốc (mẫu): two women sitting in the grass with their bikes behind them .
#   Dự đoán: three people on a dirt path .
# Figure(1000x800)
#
# Ví dụ 9:
#   Gốc (mẫu): a little girl in a flowered runs through the sand at the beach
#   Dự đoán: a young boy in a bathing suit runs along the beach .
# Figure(1000x800)
#
# Ví dụ 10:
#   Gốc (mẫu): person hiking up a grassy trail toward a large hill .
#   Dự đoán: a man is standing on a grassy hill .
# Figure(1000x800)
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `transformer_08042026_1632_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_2lketxfn (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_2lketxfn (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_2lketxfn (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_2lketxfn (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_2lketxfn (0.5s)
# wandb: ⣯ uploading artifact cnn_2lketxfn (0.5s)
# wandb: ⣟ uploading artifact cnn_2lketxfn (0.5s)
# wandb: ⡿ uploading artifact cnn_2lketxfn (0.5s)
# wandb: ⢿ uploading artifact cnn_2lketxfn (0.5s)
# wandb: ⣻ uploading artifact cnn_2lketxfn (1.0s)
# wandb: ⣽ uploading artifact cnn_2lketxfn (1.0s)
# wandb: ⣾ uploading artifact cnn_2lketxfn (1.0s)
# wandb: ⣷ uploading artifact cnn_2lketxfn (1.0s)
# wandb: ⣯ uploading artifact cnn_2lketxfn (1.0s)
# wandb: ⣟ uploading artifact cnn_2lketxfn (1.5s)
# wandb:   ↳ ⣟ transformer_08042026_1632_best.pth 26.9MB/498.3MB (0.3s)
# wandb: ⡿ uploading artifact cnn_2lketxfn (1.5s)
# wandb:   ↳ ⡿ transformer_08042026_1632_best.pth 26.9MB/498.3MB (0.3s)
# wandb: ⢿ uploading artifact cnn_2lketxfn (1.5s)
# wandb:   ↳ ⢿ transformer_08042026_1632_best.pth 26.9MB/498.3MB (0.3s)
# wandb: ⣻ uploading artifact cnn_2lketxfn (1.5s)
# wandb:   ↳ ⣻ transformer_08042026_1632_best.pth 26.9MB/498.3MB (0.3s)
# wandb: ⣽ uploading artifact cnn_2lketxfn (1.5s)
# wandb:   ↳ ⣽ transformer_08042026_1632_best.pth 26.9MB/498.3MB (0.3s)
# wandb: ⣾ uploading artifact cnn_2lketxfn (2.0s)
# wandb:   ↳ ⣾ transformer_08042026_1632_best.pth 61.6MB/498.3MB (0.8s)
# wandb: ⣷ uploading artifact cnn_2lketxfn (2.0s)
# wandb:   ↳ ⣷ transformer_08042026_1632_best.pth 61.6MB/498.3MB (0.8s)
# wandb: ⣯ uploading artifact cnn_2lketxfn (2.0s)
# wandb:   ↳ ⣯ transformer_08042026_1632_best.pth 61.6MB/498.3MB (0.8s)
# wandb: ⣟ uploading artifact cnn_2lketxfn (2.0s)
# wandb:   ↳ ⣟ transformer_08042026_1632_best.pth 61.6MB/498.3MB (0.8s)
# wandb: ⡿ uploading artifact cnn_2lketxfn (2.0s)
# wandb:   ↳ ⡿ transformer_08042026_1632_best.pth 61.6MB/498.3MB (0.8s)
# wandb: ⢿ uploading artifact cnn_2lketxfn (2.5s)
# wandb:   ↳ ⢿ transformer_08042026_1632_best.pth 113.5MB/498.3MB (1.3s)
# wandb: ⣻ uploading artifact cnn_2lketxfn (2.5s)
# wandb:   ↳ ⣻ transformer_08042026_1632_best.pth 113.5MB/498.3MB (1.3s)
# wandb: ⣽ uploading artifact cnn_2lketxfn (2.5s)
# wandb:   ↳ ⣽ transformer_08042026_1632_best.pth 113.5MB/498.3MB (1.3s)
# wandb: ⣾ uploading artifact cnn_2lketxfn (2.5s)
# wandb:   ↳ ⣾ transformer_08042026_1632_best.pth 113.5MB/498.3MB (1.3s)
# wandb: ⣷ uploading artifact cnn_2lketxfn (2.5s)
# wandb:   ↳ ⣷ transformer_08042026_1632_best.pth 113.5MB/498.3MB (1.3s)
# wandb: ⣯ uploading artifact cnn_2lketxfn (3.0s)
# wandb:   ↳ ⣯ transformer_08042026_1632_best.pth 155.5MB/498.3MB (1.8s)
# wandb: ⣟ uploading artifact cnn_2lketxfn (3.0s)
# wandb:   ↳ ⣟ transformer_08042026_1632_best.pth 155.5MB/498.3MB (1.8s)
# wandb: ⡿ uploading artifact cnn_2lketxfn (3.0s)
# wandb:   ↳ ⡿ transformer_08042026_1632_best.pth 155.5MB/498.3MB (1.8s)
# wandb: ⢿ uploading artifact cnn_2lketxfn (3.0s)
# wandb:   ↳ ⢿ transformer_08042026_1632_best.pth 155.5MB/498.3MB (1.8s)
# wandb: ⣻ uploading artifact cnn_2lketxfn (3.0s)
# wandb:   ↳ ⣻ transformer_08042026_1632_best.pth 155.5MB/498.3MB (1.8s)
# wandb: ⣽ uploading artifact cnn_2lketxfn (3.5s)
# wandb:   ↳ ⣽ transformer_08042026_1632_best.pth 204.1MB/498.3MB (2.3s)
# wandb: ⣾ uploading artifact cnn_2lketxfn (3.5s)
# wandb:   ↳ ⣾ transformer_08042026_1632_best.pth 204.1MB/498.3MB (2.3s)
# wandb: ⣷ uploading artifact cnn_2lketxfn (3.5s)
# wandb:   ↳ ⣷ transformer_08042026_1632_best.pth 204.1MB/498.3MB (2.3s)
# wandb: ⣯ uploading artifact cnn_2lketxfn (3.5s)
# wandb:   ↳ ⣯ transformer_08042026_1632_best.pth 204.1MB/498.3MB (2.3s)
# wandb: ⣟ uploading artifact cnn_2lketxfn (3.5s)
# wandb:   ↳ ⣟ transformer_08042026_1632_best.pth 204.1MB/498.3MB (2.3s)
# wandb: ⡿ uploading artifact cnn_2lketxfn (4.0s)
# wandb:   ↳ ⡿ transformer_08042026_1632_best.pth 251.4MB/498.3MB (2.8s)
# wandb: ⢿ uploading artifact cnn_2lketxfn (4.0s)
# wandb:   ↳ ⢿ transformer_08042026_1632_best.pth 251.4MB/498.3MB (2.8s)
# wandb: ⣻ uploading artifact cnn_2lketxfn (4.0s)
# wandb:   ↳ ⣻ transformer_08042026_1632_best.pth 251.4MB/498.3MB (2.8s)
# wandb: ⣽ uploading artifact cnn_2lketxfn (4.0s)
# wandb:   ↳ ⣽ transformer_08042026_1632_best.pth 251.4MB/498.3MB (2.8s)
# wandb: ⣾ uploading artifact cnn_2lketxfn (4.0s)
# wandb:   ↳ ⣾ transformer_08042026_1632_best.pth 251.4MB/498.3MB (2.8s)
# wandb: ⣷ uploading artifact cnn_2lketxfn (4.5s)
# wandb:   ↳ ⣷ transformer_08042026_1632_best.pth 294.0MB/498.3MB (3.3s)
# wandb: ⣯ uploading artifact cnn_2lketxfn (4.5s)
# wandb:   ↳ ⣯ transformer_08042026_1632_best.pth 294.0MB/498.3MB (3.3s)
# wandb: ⣟ uploading artifact cnn_2lketxfn (4.5s)
# wandb:   ↳ ⣟ transformer_08042026_1632_best.pth 294.0MB/498.3MB (3.3s)
# wandb: ⡿ uploading artifact cnn_2lketxfn (4.5s)
# wandb:   ↳ ⡿ transformer_08042026_1632_best.pth 294.0MB/498.3MB (3.3s)
# wandb: ⢿ uploading artifact cnn_2lketxfn (4.5s)
# wandb:   ↳ ⢿ transformer_08042026_1632_best.pth 294.0MB/498.3MB (3.3s)
# wandb: ⣻ uploading artifact cnn_2lketxfn (5.0s)
# wandb:   ↳ ⣻ transformer_08042026_1632_best.pth 345.0MB/498.3MB (3.8s)
# wandb: ⣽ uploading artifact cnn_2lketxfn (5.0s)
# wandb:   ↳ ⣽ transformer_08042026_1632_best.pth 345.0MB/498.3MB (3.8s)
# wandb: ⣾ uploading artifact cnn_2lketxfn (5.0s)
# wandb:   ↳ ⣾ transformer_08042026_1632_best.pth 345.0MB/498.3MB (3.8s)
# wandb: ⣷ uploading artifact cnn_2lketxfn (5.0s)
# wandb:   ↳ ⣷ transformer_08042026_1632_best.pth 345.0MB/498.3MB (3.8s)
# wandb: ⣯ uploading artifact cnn_2lketxfn (5.0s)
# wandb:   ↳ ⣯ transformer_08042026_1632_best.pth 345.0MB/498.3MB (3.8s)
# wandb: ⣟ uploading artifact cnn_2lketxfn (5.5s)
# wandb:   ↳ ⣟ transformer_08042026_1632_best.pth 390.9MB/498.3MB (4.3s)
# wandb: ⡿ uploading artifact cnn_2lketxfn (5.5s)
# wandb:   ↳ ⡿ transformer_08042026_1632_best.pth 390.9MB/498.3MB (4.3s)
# wandb: ⢿ uploading artifact cnn_2lketxfn (5.5s)
# wandb:   ↳ ⢿ transformer_08042026_1632_best.pth 390.9MB/498.3MB (4.3s)
# wandb: ⣻ uploading artifact cnn_2lketxfn (5.5s)
# wandb:   ↳ ⣻ transformer_08042026_1632_best.pth 390.9MB/498.3MB (4.3s)
# wandb: ⣽ uploading artifact cnn_2lketxfn (5.5s)
# wandb:   ↳ ⣽ transformer_08042026_1632_best.pth 390.9MB/498.3MB (4.3s)
# wandb: ⣾ uploading artifact cnn_2lketxfn (6.0s)
# wandb:   ↳ ⣾ transformer_08042026_1632_best.pth 435.1MB/498.3MB (4.8s)
# wandb: ⣷ uploading artifact cnn_2lketxfn (6.0s)
# wandb:   ↳ ⣷ transformer_08042026_1632_best.pth 435.1MB/498.3MB (4.8s)
# wandb: ⣯ uploading artifact cnn_2lketxfn (6.0s)
# wandb:   ↳ ⣯ transformer_08042026_1632_best.pth 435.1MB/498.3MB (4.8s)
# wandb: ⣟ uploading artifact cnn_2lketxfn (6.0s)
# wandb:   ↳ ⣟ transformer_08042026_1632_best.pth 435.1MB/498.3MB (4.8s)
# wandb: ⡿ uploading artifact cnn_2lketxfn (6.0s)
# wandb:   ↳ ⡿ transformer_08042026_1632_best.pth 435.1MB/498.3MB (4.8s)
# wandb: ⢿ uploading artifact cnn_2lketxfn (6.5s)
# wandb:   ↳ ⢿ transformer_08042026_1632_best.pth 478.0MB/498.3MB (5.3s)
# wandb: ⣻ uploading artifact cnn_2lketxfn (6.5s)
# wandb:   ↳ ⣻ transformer_08042026_1632_best.pth 478.0MB/498.3MB (5.3s)
# wandb: ⣽ uploading artifact cnn_2lketxfn (6.5s)
# wandb:   ↳ ⣽ transformer_08042026_1632_best.pth 478.0MB/498.3MB (5.3s)
# wandb: ⣾ uploading artifact cnn_2lketxfn (6.5s)
# wandb:   ↳ ⣾ transformer_08042026_1632_best.pth 478.0MB/498.3MB (5.3s)
# wandb: ⣷ uploading artifact cnn_2lketxfn (6.5s)
# wandb:   ↳ ⣷ transformer_08042026_1632_best.pth 478.0MB/498.3MB (5.3s)
# wandb: ⣯ uploading artifact cnn_2lketxfn (7.0s)
# wandb: ⣟ uploading artifact cnn_2lketxfn (7.0s)
# wandb: ⡿ uploading artifact cnn_2lketxfn (7.0s)
# wandb: ⢿ uploading artifact cnn_2lketxfn (7.0s)
# wandb: ⣻ uploading artifact cnn_2lketxfn (7.0s)
# wandb: ⣽ uploading artifact cnn_2lketxfn (7.5s)
# wandb: ⣾ uploading artifact cnn_2lketxfn (7.5s)
# wandb: ⣷ uploading artifact cnn_2lketxfn (7.5s)
# wandb:
# wandb: Run history:
# wandb:         Epoch ▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██
# wandb: Learning_Rate █████▄▄▄▄▄▂▂▂▂▂▁▁
# wandb:   Test/BLEU-1 ▁
# wandb:   Test/BLEU-2 ▁
# wandb:   Test/BLEU-3 ▁
# wandb:   Test/BLEU-4 ▁
# wandb:   Test/METEOR ▁
# wandb:  Test/ROUGE-L ▁
# wandb:    Train/Loss █▅▄▄▃▃▂▂▂▂▂▁▁▁▁▁▁
# wandb:      Val/Loss █▄▃▂▁▁▁▁▁▁▁▁▁▂▂▂▂
# wandb:
# wandb: Run summary:
# wandb:         Epoch 17
# wandb: Learning_Rate 1e-05
# wandb:   Test/BLEU-1 0.69445
# wandb:   Test/BLEU-2 0.48551
# wandb:   Test/BLEU-3 0.33585
# wandb:   Test/BLEU-4 0.23003
# wandb:   Test/METEOR 0.47148
# wandb:  Test/ROUGE-L 0.53291
# wandb:    Train/Loss 1.73712
# wandb:      Val/Loss 2.73799
# wandb:            +2 ...
# wandb:
# wandb: 🚀 View run transformer_08042026_1632 at: https://wandb.ai/phucga15062005/image-captioning/runs/2lketxfn
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/image-captioning
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260408_163335-2lketxfn/logs
#
# 		--- ALL TASKS COMPLETED! ---

# %%
# !python -m scripts.analyze_best --config transformer --env kaggle
